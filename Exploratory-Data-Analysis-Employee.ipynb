# %% [markdown]
# EDA=> PALING PENTING => penguasaan domain knowledge/business knowledge
# EDA=> paling penting => penguasaan domain knowledge / business knowledge
# feature column
# target column
# - EXPLORATORY DATA ANALYSIS => if you torture the data long enough, it will confess
# - EXPLORATORY DATA ANALYSIS
#
# langkah-langkahnya:
#     *domain knowledge
#     -define problem=latar belakang
#     -define goals
#     -find dataset
#     -definisi setiap kolom dan isinya
#     -pengecekan missing value dan gimana handling nya(modeling datanya harus lengkap semua)
#     -describe data
#     -pengecekkan data outliers(via hitungan rumus atau via boxplot)=> handling nya outliers
#     -* pengecekan dan ekstraksi kolom yang bertipe date time/tanggal
#     -analisa data =>
#         -univariate=>analisa 1 kolom
#         -bivariate-multivariate=>dua kolom lebih=>crosstab,pivot table,group by subsetting
#         -temukan insight data
#     -data visualization
#         -univariate
#         -bivariate -multivariate
#         -temukan insight
#     -kesimpulan-rekomendasi
#
#     =======modelling
# -kesimpulan - rekomendasi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("employee.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Changing object types to categories
cols = ['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']
for col in cols:
    df[col] = df[col].astype('category')

# %%
df.dtypes
# Out:
# Age                            int64
# Attrition                     object
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                      int64
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction        int64
# Gender                      category
# HourlyRate                     int64
# JobInvolvement                 int64
# JobLevel                       int64
# JobRole                     category
# JobSatisfaction                int64
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                        object
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating              int64
# ...

# %% [markdown]
# # Explore data analysis Employee
# - Definisikan Masalah terkait bisnis yang ingin anda selesaikan (Define Business Problem) : menganalisa mengapa pegawai keluar dari pekerjaannya.
# - Definisikan Tujuan EDA anda (Define Goals): faktor apa yang paling tinggi membuat pegawai keluar dari pekerjaannya. sehingga bisa dicarikan solusi terbaik dari permasalahan tersebut

# %% [markdown]
# # handling missing value and outliers

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## outliers years at company
# - years at company di cek karena untuk mengetahui kenapa beberapa pegawai bisa bertahan lama,setelah di cek outliers yang ada di years at company tidak mengganggu. karena faktor dari kolom lain. yaitu age, dilihat dari age yang sudah tua, pastinya years at company nya juga lebih lama dari yang lain

# %%
Q1 = df.describe()['YearsAtCompany']['25%']
Q3 = df.describe()['YearsAtCompany']['75%']
IQR = Q3 - Q1
Upper_Fence = Q3 + (1.5 * IQR)
Lower_Fence = Q1 - (1.5 * IQR)
print(IQR)
# Out:
# 6.0

# %%
df[(df['YearsAtCompany'] < Lower_Fence) | (df['YearsAtCompany'] > Upper_Fence)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 18     53        No      Travel_Rarely       1219                   Sales
# 28     44        No      Travel_Rarely        477  Research & Development
# 45     41       Yes      Travel_Rarely       1360  Research & Development
# 62     50        No      Travel_Rarely        989  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 90     40        No  Travel_Frequently        530  Research & Development
# 98     58        No      Travel_Rarely        682                   Sales
# 119    43        No  Travel_Frequently        394                   Sales
# 123    51        No      Travel_Rarely        684  Research & Development
# 126    58       Yes      Travel_Rarely        147  Research & Development
# 150    40        No  Travel_Frequently       1395  Research & Development
# 178    46        No      Travel_Rarely        526                   Sales
# ...

# %%
plt.hist(df['YearsAtCompany'])
# Out:
# (array([470., 472., 314.,  76.,  45.,  58.,  16.,   6.,   9.,   4.]),
#  array([ 0.,  4.,  8., 12., 16., 20., 24., 28., 32., 36., 40.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## outliers Performance Rating
# - untuk outliers performance rating itu terdapat pada nilai 4 , 4 itu masih termasuk kategori nilai. maka tidak mengganggu

# %%
Q1 = df.describe()['PerformanceRating']['25%']
Q3 = df.describe()['PerformanceRating']['75%']
IQR = Q3 - Q1
Upper_Fence = Q3 + (1.5 * IQR)
Lower_Fence = Q1 - (1.5 * IQR)
print(IQR)
df[(df['PerformanceRating'] < Lower_Fence) | (df['PerformanceRating'] > Upper_Fence)]
# Out:
# 0.0
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 26     32       Yes  Travel_Frequently       1125  Research & Development
# 44     30        No  Travel_Frequently        721  Research & Development
# 46     34        No         Non-Travel       1065                   Sales
# 47     37        No      Travel_Rarely        408  Research & Development
# 48     46        No  Travel_Frequently       1211                   Sales
# 52     44        No      Travel_Rarely       1488                   Sales
# 56     35        No  Travel_Frequently        853                   Sales
# ...

# %%
sns.boxplot(df['PerformanceRating'],palette='vlag')
# Out:
# /Users/risyad/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## outliers YearsWithCurrManager
# - untuk outliers YearsWithCurrManager tidak menggangnggu juga, dari segi umur dan segi YearsWithCurrManager tidak terlalu berlebihan

# %%
Q1 = df.describe()['YearsWithCurrManager']['25%']
Q3 = df.describe()['YearsWithCurrManager']['75%']
IQR = Q3 - Q1
Upper_Fence = Q3 + (1.5 * IQR)
Lower_Fence = Q1 - (1.5 * IQR)
print(IQR)
df[(df['YearsWithCurrManager'] < Lower_Fence) | (df['YearsWithCurrManager'] > Upper_Fence)]
# Out:
# 5.0
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 28     44        No  Travel_Rarely        477  Research & Development
# 123    51        No  Travel_Rarely        684  Research & Development
# 153    45        No  Travel_Rarely        194  Research & Development
# 187    55        No  Travel_Rarely        692  Research & Development
# 231    42        No  Travel_Rarely        532  Research & Development
# 386    37        No  Travel_Rarely       1107  Research & Development
# 561    52        No  Travel_Rarely        621                   Sales
# 616    51        No  Travel_Rarely       1318                   Sales
# 635    35        No  Travel_Rarely        607  Research & Development
# 686    41        No  Travel_Rarely        263  Research & Development
# 875    44        No  Travel_Rarely        200  Research & Development
# 926    43        No  Travel_Rarely        531                   Sales
# ...

# %%
sns.boxplot(df['YearsWithCurrManager'],palette='vlag')
# Out:
# /Users/risyad/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Analisis Data (Univariate dan Multivariate, Gunakan Crosstab atau Pivot_Table atau Group by ) dan Visualisasi Data (Univariate dan Multivariate, Gunakan plot sesuai dengan fungsi dan tujuannya)

# %%
df.dtypes
# Out:
# Age                            int64
# Attrition                     object
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                      int64
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction        int64
# Gender                      category
# HourlyRate                     int64
# JobInvolvement                 int64
# JobLevel                       int64
# JobRole                     category
# JobSatisfaction                int64
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                        object
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating              int64
# ...

# %% [markdown]
# # mengetahui jumlah terjadi resign pada perusahaan

# %%
hasil = df['Attrition'].apply(lambda x: 'bekerja di persuahaan' if x == 'Yes' else 'resign')

# %%
sns.countplot(trgt)
plt.title('Attrition')
plt.xlabel('Attrition Status')
plt.ylabel('banyaknya pegawai')
plt.show()
hasil.value_counts()
# Out:
# /Users/risyad/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# resign                   1233
# bekerja di persuahaan     237
# Name: Attrition, dtype: int64

# %% [markdown]
# - tabel dibawah ini menunjukan berapa banyak pekerja yang melakukan resign dari perusahaan tersebut dari perdepartemen nya

# %%
pd.crosstab(df['Department'],columns=df['Attrition'])
# Out:
# Attrition                No  Yes
# Department
# Sales                   354   92
# Research & Development  828  133
# Human Resources          51   12

# %% [markdown]
# - tabel dibawah ini menunjukan berapa banyak pekerja yang overtime, karena salah satu pekerja itu keluar dariperusahaan adalah salah satunya overtime. source: https://www.businessinsider.com/real-reasons-why-your-employees-are-quitting-2016-5?r=US&IR=T#-7
# - dan walaupun overtime menjadi salah satu penyebab resign nya karyawan, tetapi salah satu penyebab mereka bertahan ialah dari marital statusnya

# %%
pd.crosstab(index=[df['Department'],df['JobRole']],columns=[df['Attrition'],df['OverTime'],df['MaritalStatus']])
# Out:
# Attrition                                              No                 \
# OverTime                                               No
# MaritalStatus                                    Divorced Married Single
# Department             JobRole
# Sales                  Sales Executive                 40     103     63
#                        Manager                          6      14      6
#                        Sales Representative             6      22     14
# Research & Development Research Scientist              41      78     62
#                        Laboratory Technician           37      78     51
#                        Manufacturing Director          29      45     26
#                        Healthcare Representative       24      34     29
#                        Manager                         11      21      9
#                        Research Director               14      27     15
# Human Resources        Manager                          1       5      1
# ...

# %%
df['Age']
bins = [17, 21, 25, 35, 60]
group_names = ['(18-21)', '(22-25)', '(26-35)', '(36-60)']
df['Age'] = pd.cut(df['Age'], bins, labels = group_names)
# Out:
# 0       (36-60)
# 1       (36-60)
# 2       (36-60)
# 3       (26-35)
# 4       (26-35)
# 5       (26-35)
# 6       (36-60)
# 7       (26-35)
# 8       (36-60)
# 9       (36-60)
# 10      (26-35)
# 11      (26-35)
# 12      (26-35)
# 13      (26-35)
# 14      (26-35)
# 15      (26-35)
# 16      (26-35)
# 17      (22-25)
# 18      (36-60)
# 19      (36-60)
# 20      (22-25)
# 21      (36-60)
# 22      (26-35)
# 23      (18-21)
# 24      (26-35)
# 25      (36-60)
# 26      (26-35)
# 27      (36-60)
# 28      (36-60)
# 29      (36-60)
#          ...
# 1440    (36-60)
# 1441    (36-60)
# 1442    (26-35)
# 1443    (36-60)
# 1444    (36-60)
# 1445    (36-60)
# 1446    (26-35)
# 1447    (36-60)
# 1448    (36-60)
# 1449    (26-35)
# 1450    (26-35)
# 1451    (36-60)
# 1452    (36-60)
# 1453    (36-60)
# 1454    (36-60)
# 1455    (36-60)
# 1456    (26-35)
# 1457    (36-60)
# 1458    (26-35)
# 1459    (26-35)
# 1460    (26-35)
# 1461    (36-60)
# 1462    (36-60)
# 1463    (26-35)
# ...

# %%
df.dtypes
# Out:
# Age                         category
# Attrition                     object
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                      int64
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction        int64
# Gender                      category
# HourlyRate                     int64
# JobInvolvement                 int64
# JobLevel                       int64
# JobRole                     category
# JobSatisfaction                int64
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                        object
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating              int64
# ...

# %% [markdown]
# - dari bawah ini ingin mengetahui umur berapa saja yang melakukan resign kerja

# %%
pd.crosstab(df['Age'],columns=df['Attrition'])
# Out:
# Attrition   No  Yes
# Age
# (36-60)     19   22
# (26-35)     60   22
# (22-25)    490  116
# (18-21)    664   77

# %%
plt.figure(figsize=(13,9))
plt.bar(df['Age'],df['MonthlyIncome'],
       linewidth=3)
plt.title('contoh bar plot')
plt.xlabel('ini age')
plt.ylabel('ini MonthlyIncome')
plt.show()

# %%
plt.figure(figsize=(13,9))
plt.bar(df['Age'],df['HourlyRate'],
       linewidth=3)
plt.title('contoh bar plot')
plt.xlabel('ini age')
plt.ylabel('ini hourlyrate')
plt.show()

# %% [markdown]
# # Temukan Insight data berdasarkan Analisis dan Visualisasi yang telah anda lakukan
# - dari data diatas ialah untuk menahan anak muda agar tidak resign ialah menambahkan gajih mereka dan menurunkan hourly rate
# - tetapi ketika mempunya status perkawinan dan selalu dilakukan overtime, maka akan ada pertimbangan tidak akan resign dari pekerjaan

# %% [markdown]
# # Kesimpulan dan Saran yang dapat anda berikan berdasarkan hasil EDA anda
# - dilakukan penambahan gaji pada jenjang umur 26-25 karena dari situ income mereka lumayan besar, dan dilakukan juga pengurangan hourly rate pada mereka
